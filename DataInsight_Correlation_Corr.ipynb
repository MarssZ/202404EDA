# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", message="Glyph .* missing from current font.")

# 读取excel文件并获取指定列
df = pd.read_csv('Data\竞争站分析-竞争站-单站-32807333.csv', usecols=['amount', 'order_cnt', 'pay_amount', 'refuelLiters', '进站加油车量（柴油）', '站前车流量（柴油）', '进站率（柴油）'], encoding='GBK')

# 将列的数值赋值给数组array_X
array_amt = df['amount'].values

# %%
# 使用默认的pearson相关系数
correlation_matrix  = df.corr()
print(correlation_matrix )

#画出相关性的热力图
plt.rcParams['font.family'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
sns.heatmap(correlation_matrix, annot=True)
plt.title('Heat Map', fontsize=18)
# Out:
#               order_cnt    amount  pay_amount  refuelLiters  进站加油车量（柴油）  \
# order_cnt      1.000000  0.583953    0.583953      0.596992    0.346907
# amount         0.583953  1.000000    1.000000      0.996213    0.200498
# pay_amount     0.583953  1.000000    1.000000      0.996213    0.200498
# refuelLiters   0.596992  0.996213    0.996213      1.000000    0.189115
# 进站加油车量（柴油）     0.346907  0.200498    0.200498      0.189115    1.000000
# 进站率（柴油）        0.100483  0.031803    0.031803      0.017501    0.710094
# 站前车流量（柴油）      0.354960  0.265114    0.265114      0.274117    0.365447
#
#                进站率（柴油）  站前车流量（柴油）
# order_cnt     0.100483   0.354960
# amount        0.031803   0.265114
# pay_amount    0.031803   0.265114
# refuelLiters  0.017501   0.274117
# 进站加油车量（柴油）    0.710094   0.365447
# 进站率（柴油）       1.000000  -0.208811
# 站前车流量（柴油）    -0.208811   1.000000
# Text(0.5, 1.0, 'Heat Map')

# %%
# Plot
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8), dpi= 80)
sns.pairplot(
    df, 
    kind="scatter",     # "scatter" 散点图、 "reg"（绘制带有回归线的散点图）、"resid"（绘制残差图）、"kde"（绘制核密度估计图）等。
    #hue="species",      # 按 名为 species 的列的类别着色。
    plot_kws=dict(
        s=50,               # 散点图点的大小
        edgecolor="white",  # 散点图边框颜色
        linewidth=2.5)      # 散点图边框宽度
    )
plt.show()
